# %% [markdown]
# ### Demo script for loading and training an SRGAN model on ImageNet

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
from Core.datasets import ImageNet
from Core.Generator import Generator
from Core.utils import *

# %% [markdown]
# #### Initialize the dataset

# %%
PATH = './Data/'
PATH = '../Downloads/imagenet-object-localization-challenge/ILSVRC/Data/' #comment out when using above path
resized_dim = (250,250)
data = ImageNet(PATH,resized_dim)

# %% [markdown]
# #### Plotting a sample

# %%
plot_for_dataset_sample(data[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
